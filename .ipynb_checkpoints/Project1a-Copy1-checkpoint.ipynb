# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from random import random, seed

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

import sklearn.linear_model as skl

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import accuracy_score

from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.utils import resample

from sklearn.preprocessing import PolynomialFeatures

# %%
# Make data.
x = np.arange(0, 1, 0.05)
y = np.arange(0, 1, 0.05)
x, y = np.meshgrid(x,y)

def FrankeFunction(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return term1 + term2 + term3 + term4


z = FrankeFunction(x, y)

fig = plt.figure()
ax = fig.gca(projection='3d')

# Plot the surface.
surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-0.10, 1.40)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
def CreateDesignMatrix_X(x, y, n = 5):
    if len(x.shape) > 1:
        x = np.ravel(x)
        y = np.ravel(y)
        
    N = len(x)
    l = int((n+1)*(n+2)/2)
    X = np.ones((N,l))
        
    for i in range(1,n+1):
        q = int((i)*(i+1)/2)
        for k in range(i+1):
            X[:,q+k] = x**(i-k) * y**k
    return X

# %%
n_x = 100   # number of points
m = 5        # degree of polynomial

# sort the random values, else your fit will go crazy
#x = np.sort((np.random.uniform(0, 1, n_x)))
#y = np.sort(np.random.uniform(0, 1, n_x))

x = np.linspace(0, 1, n_x)
y = np.linspace(0, 1, n_x)

# use the meshgrid functionality, very useful
x, y = np.meshgrid(x,y)
z = FrankeFunction(x,y)

#Transform from matrices to vectors
x_1 = np.ravel(x)
y_1 = np.ravel(y)
n = int(len(x_1))
z_true = np.ravel(z)
z_1 = np.ravel(z) + np.random.normal(size=n)*1 #np.random.random(n) * 1

# finally create the design matrix
X = CreateDesignMatrix_X(x_1, y_1, n=m)

# %% [markdown]
# z_1 is the function that gives the data, X is the design matrix
#
# Then inverse the matrix and find β, and perform the linear regression (where ztilde is the model):

# %%
beta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(z_1)
ztilde = X @ beta

# %%
# For the true function (without the noise)

beta_t = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(z_true)
ztilde_t = X @ beta_t

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_zlim3d(-0.2, 1.2)

#"""
ax1.scatter(x, y, z, 
           alpha=0.5, 
           s=0.1, 
           color='black'
           )
"""
ax1.scatter(x, y, z_1.reshape(x.shape), 
           alpha=0.5, 
           s=0.1, 
           color='black'
           )
"""
ax1.plot_surface(x, y, ztilde.reshape(x.shape), 
                alpha=0.5, 
                cmap=cm.coolwarm,
                )
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.title(f'OLS regression fit')
plt.show()

# %% [markdown]
# Find the confidence intervals of the parameters β by computing their variances:
# ?????

# %%
np.var(beta)
# Out:
# 685.7031248276938

# %% [markdown]
# Next we evaluate the Mean Squared error (MSE) and the R2 score function for the model (ztilde). We evaluate it with the real FrankeFunction, the one without the noise.

# %%
def MSE(z_data, z_model):
    n = np.size(z_model)
    return np.sum((z_data-z_model)**2)/n

print(MSE(z_true, ztilde))
# Out:
# 0.0049504233527310456

# %% [markdown]
# The MSE is ideally zero, since the smaller the value the better the fit. Here we observe an MSE of 0.09, which is pretty low, therefore indicating a good fit of the model.

# %%
def R2(z_data, z_model):
    return 1 - np.sum((z_data - z_model) ** 2) / np.sum((z_data - np.mean(z_model)) ** 2)

print(R2(z_true, ztilde))
# Out:
# 0.9401402973361159

# %% [markdown]
# The R2 score gives the coefficient of determination, which indicates how well the model predicts future samples. The best score would be 1.0. Given that the model has a score of 0.5 , this indicates that the model would explain 50% of the future samples correct, which is quite low (not sure if we can say this though).

# %% [markdown]
# # Part b) Resampling techniques, adding more complexity

# %% [markdown]
# First split the dataset in training data and test data

# %%
X_train, X_test, z_train, z_test, z_true_train, z_true_test = train_test_split(X, z_1, z_true, test_size=0.2)

# Get the new model from the training data
beta2 = np.linalg.inv(X_train.T.dot(X_train)).dot(X_train.T).dot(z_train)
ztilde1 = X_train @ beta2

# And the predictions for the test data
zpredict = X_test @ beta2

# %%
print("Training MSE: %0.4f" % MSE(z_train, ztilde1))
print("Test MSE: %0.4f" % MSE(z_test, zpredict))
print("True MSE: %0.4f" % MSE(z_true_test, zpredict))

print("Training R2: %0.4f" % R2(z_train, ztilde1))
print("Test R2: %0.4f" % R2(z_test, zpredict))
print("True R2: %0.4f" % R2(z_true_test, zpredict))
# Out:
# Training MSE: 1.0127
# Test MSE: 0.9459
# True MSE: 0.0052
# Training R2: 0.0838
# Test R2: 0.0883
# True R2: 0.9368

# %% [markdown]
# The big difference between the R2 score for the test and true data are not weird, only the r2 score for the true data is interesting here. Because of the noise the R2 score for the test data is not very relevant. The training MSE can be below 1 but should be around one because your noise is * 1. The test MSE however should be 1 or slightly above, and it is kind of weird that it is smaller than 1 here, but it could be due to the small test size we are using. (when we use 1000 datapoints instead of 100 the mse indeed goes above 1

# %% [markdown]
# K-fold cross validation

# %%
# Initialize a KFold instance
k = 10
kfold = KFold(n_splits = k, shuffle=True)

# %%
def cross_validation(x, y, k):
    n = len(x)
    
    indexes = np.arange(y.shape[0])
    np.random.shuffle(indexes)
    x = x[indexes]
    y = y[indexes]
    
    r2_test = []
    mse_test = []
    for i in range(k):
        x_train = np.concatenate((x[:int(i*n/k)], x[int((i + 1)*n/k): ]), axis = 0)
        x_test = x[int(i*n/k):int((i + 1)*n/k)]
        y_train = np.concatenate((y[:int(i*n/k)], y[int((i + 1)*n/k): ]), axis = 0)
        y_test = y[int(i*n/k):int((i + 1)*n/k)]

        beta = np.linalg.inv(x_train.T.dot(x_train)).dot(x_train.T).dot(y_train)
        ytilde = x_train @ beta
        ypredict = x_test @ beta
        
        mse_test.append(MSE(y_test, ypredict))
        r2_test.append(R2(y_test, ypredict))
    
    r2_test = np.array(r2_test)
    mse_test = np.array(mse_test)
    print("R2-Score: %0.3f (+/- %0.3f)" % (r2_test.mean(), r2_test.std() * 2))
    print("MSE-Score: %0.5f (+/- %0.5f)" % (mse_test.mean(), mse_test.std() * 2))
        
    return r2_test, mse_test

# %%
r, m = cross_validation(X, z_1, k)
# Out:
# R2-Score: 0.072 (+/- 0.020)
# MSE-Score: 1.00846 (+/- 0.08606)

# %%
print(r)
# Out:
# [0.06258702 0.0572331  0.09272495 0.06967053 0.07336827 0.06619959
#  0.08429681 0.07092021 0.0637294  0.07841033]

# %% [markdown]
# Perform the sk-learn cross-validation to estimate R2 and MSE

# %%
linreg = skl.LinearRegression()
linreg.fit(X_train, z_train)

ztilde2 = linreg.predict(X_test)

# %%
scores_test = cross_val_score(linreg, X_test, z_test, cv = kfold)
print(scores_test)

scores_true = cross_val_score(linreg, X_test, z_true_test, cv = kfold)
print(scores_true)
# Out:
# [0.06555811 0.02275717 0.0241529  0.04751325 0.0734285  0.10455003
#  0.04911964 0.09632295 0.10141275 0.12344397]
# [0.97824779 0.97620333 0.97928623 0.97896716 0.97471415 0.97732761
#  0.96919596 0.97853896 0.97565703 0.97779367]

# %%
print("R2-Score noisy data: %0.2f (+/- %0.2f)" % (scores_test.mean(), scores_test.std() * 2))
print("R2-Score real data: %0.2f (+/- %0.2f)" % (scores_true.mean(), scores_true.std() * 2))
# Out:
# R2-Score noisy data: 0.07 (+/- 0.07)
# R2-Score real data: 0.98 (+/- 0.01)

# %%
scores_mse_test = cross_val_score(linreg, X_test, z_test, scoring='neg_mean_squared_error', cv=kfold)
scores_mse_true = cross_val_score(linreg, X_test, z_true_test, scoring='neg_mean_squared_error', cv=kfold)

# %%
estimated_mse_test = np.mean(-scores_mse_test)
estimated_mse_true = np.mean(-scores_mse_true)

print('MSE-score noisy data:', estimated_mse_test)
print('MSE-score real data:', estimated_mse_true)
# Out:
# MSE-score noisy data: 1.0176498355881816
# MSE-score real data: 0.0019712941890896118

# %% [markdown]
# The R2-score and MSE are better for the real data then for the test data, which shows that the model does not predict the noise but the data, which is positive

# %% [markdown]
# # Part C) Bias-variance tradeoff

# %%
maxdegree = 25

testerror = np.zeros(maxdegree)
trainerror = np.zeros(maxdegree)
bias = np.zeros(maxdegree)
variance = np.zeros(maxdegree)
polydegree = np.zeros(maxdegree)

# %%
testerror = np.zeros(maxdegree)
trainingerror = np.zeros(maxdegree)
polynomial = np.zeros(maxdegree)

trials = 10

for polydegree in range(1, maxdegree):
    polynomial[polydegree] = polydegree
    for degree in range(polydegree):
        DM = CreateDesignMatrix_X(x_1, y_1, n=degree)

    testerror[polydegree] = 0.0
    trainingerror[polydegree] = 0.0
    for samples in range(trials):
        DM_train, DM_test, z_1_train, z_1_test = train_test_split(DM, z_1, test_size=0.2, shuffle=False)

        model = LinearRegression(fit_intercept=True).fit(DM_train, z_1_train)
        zpred = model.predict(DM_train)
        ztilde = model.predict(DM_test)
        testerror[polydegree] += mean_squared_error(z_1_test, ztilde)
        trainingerror[polydegree] += mean_squared_error(z_1_train, zpred) 

    testerror[polydegree] /= trials
    trainingerror[polydegree] /= trials
    #print("Degree of polynomial: %3d"% polynomial[polydegree])
    #print("Mean squared error on training data: %.8f" % trainingerror[polydegree])
    #print("Mean squared error on test data: %.8f" % testerror[polydegree])

plt.plot(polynomial, np.log10(trainingerror), label='Training Error')
plt.plot(polynomial, np.log10(testerror), label='Test Error')
plt.xlabel('Polynomial degree')
plt.ylabel('log10[MSE]')
plt.legend()
plt.show()
# Out:
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log10

# %%
z_test.shape
# Out:
# (2000,)

# %%
# Out:
# array([ 1.66591854, -0.21303086,  0.39894677, ...,  1.47836091,
#         1.40853293, -1.37934284])

# %%
degrees = np.arange(1,15)

k = 5
kfold = KFold(n_splits = k, shuffle=True)

array_size_thingy=len(z_test)

z_1 = z_1.reshape(-1,1)
print(z_1.shape)
print(z_1)

error = []
bias = []
variance = []
for deg in degrees:
    z_pred = np.empty((array_size_thingy, k))
    
    j=0
    X2 = CreateDesignMatrix_X(x_1, y_1, n=deg)
    model = skl.LinearRegression(fit_intercept=False)

    for train_inds, test_inds in kfold.split(z_1):
        xtrain = X2[train_inds]
        ztrain= z_1[train_inds]
        xtest = X2[test_inds]
        ztest = z_1[test_inds]
        z_pred[:,j] = model.fit(xtrain, ztrain).predict(xtest).ravel()
        
        j+=1

    err = np.mean(np.mean((ztest - z_pred)**2, axis=1, keepdims=True) )
    bi = np.mean( (ztest - np.mean(z_pred, axis=1, keepdims=True))**2 )
    var = np.mean( np.var(z_pred, axis=1, keepdims=True) )
    error.append(err)
    bias.append(bi)
    variance.append(var)

max_pd = 15 #max polynomial degree to plot to

plt.figure()
plt.plot(degrees[:max_pd],error[:max_pd],'k',label='MSE')
plt.plot(degrees[:max_pd],bias[:max_pd],'b',label='Bias^2')
plt.plot(degrees[:max_pd],variance[:max_pd],'y',label='Var')
summ=np.zeros(len(variance))
for i in range(len(error)):
    summ[i]=variance[i]+bias[i]
plt.plot(degrees[:max_pd],summ[:max_pd],'ro',label='sum')

plt.xlabel('Polynomial degree')
plt.ylabel('MSE CV')
plt.legend()
plt.show()
# Out:
# (10000, 1)
# [[ 1.66591854]
#  [-0.21303086]
#  [ 0.39894677]
#  ...
#  [ 1.47836091]
#  [ 1.40853293]
#  [-1.37934284]]

# %% [markdown]
# # Part D) Ridge Regression on the Franke function with resampling

# %% [markdown]
# First remove the first column (the intercept) so that this one is not penalised by lambda (???) You don't need to remove the intercept column for this project. Normally, if you remove the intercept column you also have to take the mean blabla something

# %%
_lambda = 10**-2

# %%
betaridge = np.linalg.inv(X_train.T.dot(X_train)+(_lambda*np.eye(len(X_train[0])))).dot(X_train.T).dot(z_train)
zridge = X_train @ betaridge

ridge_predict = X_test @ betaridge

# %%
print("var(beta) OLS:", np.var(beta))
print("var(beta) ridge:", np.var(betaridge))
# Out:
# var(beta) OLS: 386.37780040219076
# var(beta) ridge: 27.64757912446408

# %%
print("MSE OLS:", MSE(z_true_test, zpredict))
print("MSE ridge:", MSE(z_true_test, ridge_predict))
# Out:
# MSE OLS: 0.003414051081738338
# MSE ridge: 0.004838755355778765

# %%
print("R2 OLS:", R2(z_true_test, zpredict))
print("R2 Ridge:", R2(z_true_test, ridge_predict))
# Out:
# R2 OLS: 0.9600565864670063
# R2 Ridge: 0.9433911358813973

# %% [markdown]
# The ridge regression for different lambdas, to find out which lambda is best

# %%
nlambdas = 500
lambdas = np.logspace(-7, 5, nlambdas)

k = 10
kfold = KFold(n_splits = k, shuffle=True)

mse_scores_KFold = np.zeros((nlambdas, k))
r2_scores_KFold = np.zeros((nlambdas, k))

i = 0
for lmb in lambdas:
    betaridge1 = np.linalg.inv(X_train.T.dot(X_train)+(lmb*np.eye(len(X_train[0])))).dot(X_train.T).dot(z_train)
    j = 0
    for train_inds, test_inds in kfold.split(x):
        Xtrain_r = X[train_inds]
        ztrain_r = z_1[train_inds]

        Xtest_r = X[test_inds]
        ztest_r = z_true[test_inds]
        
        zpred_r = Xtest_r @ betaridge1

        mse_scores_KFold[i,j] = np.sum((zpred_r - ztest_r)**2)/np.size(zpred_r)
        #r2_scores_KFold[i,j] = 1 - np.sum((ztest_r - zpred_r) ** 2) / np.sum((ztest_r - np.mean(zpred_r)) ** 2)

        j += 1
    i += 1

estimated_mse_KFold = np.mean(mse_scores_KFold, axis = 1)
#estimated_r2_KFold = np.mean(r2_scores_KFold, axis = 1)

# %%
plt.figure()

plt.plot(np.log10(lambdas), estimated_mse_KFold, 'r--', label = 'mse_KFold')

plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# The same with sklearn and GridSearchCV.
# sklearn automatically splits the data (because of the CV) so put in the whole dataset here, and not the train data! it tests on the noisy data though, that's where the difference comes from. The negative MSE means that it is just the other side of the MSE so you can 'ignore' the minus sign

# %%
param_grid = {'alpha': lambdas}

ridge = Ridge()

ridge_regressor = GridSearchCV(ridge, param_grid, scoring='neg_mean_squared_error', cv=kfold)
ridge_regressor.fit(X, z_1)

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 0.0014465073385216472}
# -1.024432343828672

# %%
nlambdas = 500
lambdas = np.logspace(-7, 5, nlambdas)

k = 10
kfold = KFold(n_splits = k, shuffle=True)

estimated_mse_sklearn = np.zeros(nlambdas)

i = 0
for lmb in lambdas:
    ridge = Ridge(alpha = lmb)

    estimated_mse_folds = cross_val_score(ridge, X, z_1, scoring='neg_mean_squared_error', cv=kfold)
    estimated_mse_sklearn[i] = np.mean(-estimated_mse_folds)
    i += 1

print(np.mean(estimated_mse_sklearn))
# Out:
# 1.0352687273571615

# %%
plt.figure()

plt.plot(np.log10(lambdas), estimated_mse_sklearn, 'b--', label = 'mse_sklearn')
plt.plot(np.log10(lambdas), estimated_mse_KFold, 'r--', label = 'mse_KFold')

plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# # Part E) Lasso Regression on the Franke function with resampling

# %% [markdown]
# Start by finding the optimal value for lambda for lasso, using GridSearchCV

# %%
nlambdas = 500
lambdas_lasso = np.logspace(-4, 10, nlambdas)
param_grid_lasso = {'alpha': lambdas_lasso}

lasso = Lasso(precompute = True, tol = 0.001)

lasso_regressor = GridSearchCV(lasso, param_grid_lasso, scoring='neg_mean_squared_error', cv=10)
lasso_regressor.fit(X, z_1)

print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172.96647371305698, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232.96702714757066, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149.6266920490416, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.03199991282872, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179.2479610011178, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 289.50652448519577, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 454.8571408872558, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.1270326546537, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 279.8858559876335, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 503.2165503982533, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127.23593682639512, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173.79335998448732, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.90509003181796, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.129833375420276, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149.0950469208292, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 227.1664838586703, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304.3550348395911, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.80523920959058, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178.89847198351072, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.45598438858906, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88.6343867984242, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121.9019365566528, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.14238815608769, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.17242658969917, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.18198747805764, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178.52296423398275, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173.16289846087784, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.71232577222418, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147.19393447629864, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209.14620490027028, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.27074151526449, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.74378387744127, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.750427135693826, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.73188009371188, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.9701023587986, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99.04415816313303, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79.86361108229266, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.86054447248807, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122.4079059567357, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.75056928048616, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.74989893453312, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.49770928391081, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.950579769016258, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.19351201033533, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128.519158368872, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.370444985092035, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.91782830557077, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.23484914539677, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71.00032284498593, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.162723703595475, tolerance: 9.85051643705757
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.81732076802473, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.44743287586971, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.13491967309528, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.61743517557443, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.14402595883439, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.37887170060094, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.65596368498063, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.2785274007947, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60.173564569149676, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.401914078254777, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.211179229951085, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.91018865827755, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.647145876928334, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.37128073175245, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.3448330147512, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.70553714732341, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.570485573229234, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.207841890971395, tolerance: 9.909900497268735
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.331667344669768, tolerance: 9.803966370156354
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.216274300952136, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.166862884390866, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.68640288114875, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88.78018841402809, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.14297322694074, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.902585588199145, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.46439231059776, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.174185237869096, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.8879611292723, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.751736311853165, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.6410761560337, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.501364313662634, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.59948541185804, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.293326608252755, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.519789036372458, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.789681749994998, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.157544212239372, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151.33005544306525, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.23739885049872, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.10803537281754, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.402815992774777, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.67399474235026, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.384266756140278, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.91736329082596, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.23901246620062, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.988703885963332, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.33908570974381, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.445010698767874, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.774799906421322, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.636242837232203, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.72450034202666, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.46973956205693, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.154349665646805, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.016582860605922, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.804904016305954, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.378311904349175, tolerance: 9.8655688755306
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.36824561526555, tolerance: 9.957611758316304
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.309349513740017, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.176687013055925, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.349985324195586, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.506803826439864, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.612711782219776, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.696237475998714, tolerance: 10.069048083383768
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.156081578441444, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.018578665309178, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.14560978267764, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.288357293848094, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.282995071882397, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.856699108428074, tolerance: 9.940118953557933
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.9145741542452, tolerance: 9.967627415850137
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.293499464090928, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.447213711886434, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.41589299937732, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.664442411120035, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.613469065263416, tolerance: 9.834626629494586
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.773124856264985, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.78857098334811, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.938462023505053, tolerance: 10.074087102130827
#   tol, rng, random, positive)
# {'alpha': 0.0002635370519267393}
# -1.0310593718060275
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.980318283529414, tolerance: 11.036210229998028
#   tol, rng, random, positive)

# %% [markdown]
# The optimal value for lambda is around 3.2^-4. If we use this value for lambda we can compare the MSE and R2 scores for all three models

# %%
l_lambda = 0.00032

clf_lasso = skl.Lasso(alpha=l_lambda, precompute = True, tol = 0.01).fit(X_train, z_train)
pred_lasso = clf_lasso.predict(X_test)

# %%
print("MSE OLS:", MSE(z_true_test, zpredict))
print("MSE ridge:", MSE(z_true_test, ridge_predict))
print("MSE lasso:", MSE(z_true_test, pred_lasso))
# Out:
# MSE OLS: 0.003414051081738338
# MSE ridge: 0.004838755355778765
# MSE lasso: 0.011688937735854601

# %%
print("R2 OLS:", R2(z_true_test, zpredict))
print("R2 Ridge:", R2(z_true_test, ridge_predict))
print("R2 lasso:", R2(z_true_test, pred_lasso))
# Out:
# R2 OLS: 0.9600565864670063
# R2 Ridge: 0.9433911358813973
# R2 lasso: 0.8632105930172186
