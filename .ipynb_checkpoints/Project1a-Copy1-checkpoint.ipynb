# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from random import random, seed

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

import sklearn.linear_model as skl
from sklearn.linear_model import LinearRegression

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import accuracy_score

from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.utils import resample

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso

# %%
# Make data.
x = np.arange(0, 1, 0.05)
y = np.arange(0, 1, 0.05)
x, y = np.meshgrid(x,y)

def FrankeFunction(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return term1 + term2 + term3 + term4


z = FrankeFunction(x, y)

fig = plt.figure()
ax = fig.gca(projection='3d')

# Plot the surface.
surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-0.10, 1.40)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
def CreateDesignMatrix_X(x, y, n = 5):
    if len(x.shape) > 1:
        x = np.ravel(x)
        y = np.ravel(y)
        
    N = len(x)
    l = int((n+1)*(n+2)/2)
    X = np.ones((N,l))
        
    for i in range(1,n+1):
        q = int((i)*(i+1)/2)
        for k in range(i+1):
            X[:,q+k] = x**(i-k) * y**k
    return X

# %%
n_x = 100   # number of points
m = 5        # degree of polynomial

# sort the random values, else your fit will go crazy
#x = np.sort((np.random.uniform(0, 1, n_x)))
#y = np.sort(np.random.uniform(0, 1, n_x))

x = np.linspace(0, 1, n_x)
y = np.linspace(0, 1, n_x)

# use the meshgrid functionality, very useful
x, y = np.meshgrid(x,y)
z = FrankeFunction(x,y)

#Transform from matrices to vectors
x_1 = np.ravel(x)
y_1 = np.ravel(y)
n = int(len(x_1))
z_1 = np.ravel(z) + np.random.random(n) * 1
z_true = np.ravel(z)


# finally create the design matrix
X = CreateDesignMatrix_X(x_1, y_1, n=m)

# %% [markdown]
# z_1 is the function that gives the data, X is the design matrix
#
# Then inverse the matrix and find β, and perform the linear regression (where ztilde is the model):

# %%
beta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(z_1)
ztilde = X @ beta

# %%
# For the true function (without the noise)

beta_t = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(z_true)
ztilde_t = X @ beta_t

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.set_zlim3d(-0.2, 1.2)

ax1.scatter(x, y, z, 
           alpha=1, 
           s=0.1, 
           color='black'
           )

ax1.plot_surface(x, y, ztilde_t.reshape(x.shape), 
                alpha=0.4, 
                cmap=cm.coolwarm,
                )

plt.title(f'OLS regression fit')
plt.show()

# %% [markdown]
# Find the confidence intervals of the parameters β by computing their variances:
# ?????

# %%
np.var(beta)
# Out:
# 620.0951859702437

# %% [markdown]
# Next we evaluate the Mean Squared error (MSE) and the R2 score function for the model (ztilde). We evaluate it with the real FrankeFunction, the one without the noise.

# %%
def MSE(z_data, z_model):
    n = np.size(z_model)
    return np.sum((z_data-z_model)**2)/n

print(MSE(z_true, ztilde))
# Out:
# 0.2509239302733229

# %% [markdown]
# The MSE is ideally zero, since the smaller the value the better the fit. Here we observe an MSE of 0.09, which is pretty low, therefore indicating a good fit of the model.

# %%
def R2(z_data, z_model):
    return 1 - np.sum((z_data - z_model) ** 2) / np.sum((z_data - np.mean(z_model)) ** 2)

print(R2(z_true, ztilde))
# Out:
# 0.2421153826238306

# %% [markdown]
# The R2 score gives the coefficient of determination, which indicates how well the model predicts future samples. The best score would be 1.0. Given that the model has a score of 0.5 , this indicates that the model would explain 50% of the future samples correct, which is quite low (not sure if we can say this though).

# %% [markdown]
# # Part b) Resampling techniques, adding more complexity

# %% [markdown]
# First split the dataset in training data and test data

# %%
X_train, X_test, z_train, z_test, z_true_train, z_true_test = train_test_split(X, z_1, z_true, test_size=0.2)

# Get the new model from the training data
beta2 = np.linalg.inv(X_train.T.dot(X_train)).dot(X_train.T).dot(z_train)
ztilde1 = X_train @ beta2

# And the predictions for the test data
zpredict = X_test @ beta2

# %%
print("Training MSE:", MSE(z_train, ztilde1))
print("Test MSE:", MSE(z_true_test, zpredict))

print("Training R2:", R2(z_train, ztilde1))
print("Test R2:", R2(z_true_test, zpredict))
# Out:
# Training MSE: 0.085190059157989
# Test MSE: 0.25160969566138636
# Training R2: 0.4830422512547835
# Test R2: 0.2408900047654775

# %% [markdown]
# K-fold cross validation

# %%
# Initialize a KFold instance
k = 10
kfold = KFold(n_splits = k, shuffle=True)

# %%
def cross_validation(x, y, k):
    n = len(x)
    
    indexes = np.arange(y.shape[0])
    np.random.shuffle(indexes)
    x = x[indexes]
    y = y[indexes]
    
    r2_test = []
    mse_test = []
    for i in range(k):
        x_train = np.concatenate((x[:int(i*n/k)], x[int((i + 1)*n/k): ]), axis = 0)
        x_test = x[int(i*n/k):int((i + 1)*n/k)]
        y_train = np.concatenate((y[:int(i*n/k)], y[int((i + 1)*n/k): ]), axis = 0)
        y_test = y[int(i*n/k):int((i + 1)*n/k)]

        beta = np.linalg.inv(x_train.T.dot(x_train)).dot(x_train.T).dot(y_train)
        ytilde = x_train @ beta
        ypredict = x_test @ beta
        
        mse_test.append(MSE(y_test, ypredict))
        r2_test.append(R2(y_test, ypredict))
    
    r2_test = np.array(r2_test)
    mse_test = np.array(mse_test)
    print("R2-Score: %0.3f (+/- %0.3f)" % (r2_test.mean(), r2_test.std() * 2))
    print("MSE-Score: %0.5f (+/- %0.5f)" % (mse_test.mean(), mse_test.std() * 2))
        
    return r2_test, mse_test

# %%
r, m = cross_validation(X, z_1, k)
# Out:
# R2-Score: 0.478 (+/- 0.048)
# MSE-Score: 0.08554 (+/- 0.00403)

# %%
print(r)
# Out:
# [0.49721129 0.5144959  0.47800425 0.45444503 0.48193067 0.49231672
#  0.47273217 0.48771581 0.47976761 0.42100452]

# %% [markdown]
# Perform the sk-learn cross-validation to estimate R2 and MSE

# %%
linreg = skl.LinearRegression()
linreg.fit(X_train, z_train)

ztilde2 = linreg.predict(X_test)

# %%
scores_test = cross_val_score(linreg, X_test, z_test, cv = kfold)
print(scores_test)

scores_true = cross_val_score(linreg, X_test, z_true_test, cv = kfold)
print(scores_true)
# Out:
# [0.50898707 0.42307995 0.50796717 0.43256174 0.50112816 0.4392261
#  0.46726804 0.43413268 0.45751523 0.47380227]
# [0.97147777 0.97506862 0.97792676 0.97330142 0.97357383 0.97557565
#  0.97566267 0.96823794 0.97211882 0.97386936]

# %%
print("R2-Score noisy data: %0.2f (+/- %0.2f)" % (scores_test.mean(), scores_test.std() * 2))
print("R2-Score real data: %0.2f (+/- %0.2f)" % (scores_true.mean(), scores_true.std() * 2))
# Out:
# R2-Score noisy data: 0.46 (+/- 0.06)
# R2-Score real data: 0.97 (+/- 0.01)

# %%
scores_mse_test = cross_val_score(linreg, X_test, z_test, scoring='neg_mean_squared_error', cv=kfold)
scores_mse_true = cross_val_score(linreg, X_test, z_true_test, scoring='neg_mean_squared_error', cv=kfold)

# %%
estimated_mse_test = np.mean(-scores_mse_test)
estimated_mse_true = np.mean(-scores_mse_true)

print('MSE-score noisy data:', estimated_mse_test)
print('MSE-score real data:', estimated_mse_true)
# Out:
# MSE-score noisy data: 0.0864468415370257
# MSE-score real data: 0.0021410996151287696

# %% [markdown]
# The R2-score and MSE are better for the real data then for the test data, which shows that the model does not predict the noise but the data, which is positive

# %% [markdown]
# # Part C) Bias-variance tradeoff

# %%
maxdegree = 25

testerror = np.zeros(maxdegree)
trainerror = np.zeros(maxdegree)
bias = np.zeros(maxdegree)
variance = np.zeros(maxdegree)
polydegree = np.zeros(maxdegree)

# %%
testerror = np.zeros(maxdegree)
trainingerror = np.zeros(maxdegree)
polynomial = np.zeros(maxdegree)

trials = 10

for polydegree in range(1, maxdegree):
    polynomial[polydegree] = polydegree
    for degree in range(polydegree):
        DM = CreateDesignMatrix_X(x_1, y_1, n=degree)

    testerror[polydegree] = 0.0
    trainingerror[polydegree] = 0.0
    for samples in range(trials):
        DM_train, DM_test, z_1_train, z_1_test = train_test_split(DM, z_1, test_size=0.2, shuffle=False)

        model = LinearRegression(fit_intercept=True).fit(DM_train, z_1_train)
        zpred = model.predict(DM_train)
        ztilde = model.predict(DM_test)
        testerror[polydegree] += mean_squared_error(z_1_test, ztilde)
        trainingerror[polydegree] += mean_squared_error(z_1_train, zpred) 

    testerror[polydegree] /= trials
    trainingerror[polydegree] /= trials
    #print("Degree of polynomial: %3d"% polynomial[polydegree])
    #print("Mean squared error on training data: %.8f" % trainingerror[polydegree])
    #print("Mean squared error on test data: %.8f" % testerror[polydegree])

plt.plot(polynomial, np.log10(trainingerror), label='Training Error')
plt.plot(polynomial, np.log10(testerror), label='Test Error')
plt.xlabel('Polynomial degree')
plt.ylabel('log10[MSE]')
plt.legend()
plt.show()
# Out:
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# Now for multiple degrees:

# %%
for degree in range(maxdegree):
    model = make_pipeline(PolynomialFeatures(degree=degree), LinearRegression(fit_intercept=False))
    x_, z_ = resample(X_train, z_train)
    z_pred[degree] = model.fit(x_, z_).predict(X_test).ravel()

# %%
polydegree[degree] = degree
error[degree] = np.mean(np.mean((z_test - z_pred)**2, axis=1, keepdims=True))
bias[degree] = np.mean((z_test - np.mean(z_pred, axis=1, keepdims=True))**2)
variance[degree] = np.mean(np.var(z_pred, axis=1, keepdims=True))
print('Polynomial degree:', degree)
print('Error:', error[degree])
print('Bias^2:', bias[degree])
print('Var:', variance[degree])
print('{} >= {} + {} = {}'.format(error[degree], bias[degree], variance[degree], bias[degree]+variance[degree]))

# %% [markdown]
# # Part D) Ridge Regression on the Franke function with resampling

# %% [markdown]
# First remove the first column (the intercept) so that this one is not penalised by lambda

# %%
X_new = X[:,1:]

# %% [markdown]
# Create new train and test data with the new designmatrix Xnew where the intercept column is removed

# %%
Xnew_train, Xnew_test, z_train, z_test = train_test_split(X_new, z_1, test_size=0.2)

# %%
_lambda = 10**4

# %%
betaridge = np.linalg.inv(Xnew_train.T.dot(Xnew_train)+(_lambda*np.eye(len(Xnew_train[0])))).dot(Xnew_train.T).dot(z_train)
zridge = Xnew_train @ betaridge

ridge_predict = Xnew_test @ betaridge

# %%
print("var(beta) OLS:", np.var(beta))
print("var(beta) ridge:", np.var(betaridge))
# Out:
# var(beta) OLS: 620.0951859702437
# var(beta) ridge: 0.002269071060216334

# %%
print("MSE OLS:", MSE(z_true_test, zpredict))
print("MSE ridge:", MSE(z_true_test, ridge_predict))
# Out:
# MSE OLS: 0.25160969566138636
# MSE ridge: 0.12755069585117235

# %%
print("R2 OLS:", R2(z_true_test, zpredict))
print("R2 Ridge:", R2(z_true_test, ridge_predict))
# Out:
# R2 OLS: 0.2408900047654775
# R2 Ridge: -0.36222661674735845

# %% [markdown]
# The ridge regression for different lambdas, to find out which lambda is best

# %%
nlambdas = 500
lambdas = np.logspace(-5, 10, nlambdas)

k = 10
kfold = KFold(n_splits = k, shuffle=True)

mse_scores_KFold = np.zeros((nlambdas, k))
r2_scores_KFold = np.zeros((nlambdas, k))

i = 0
for lmb in lambdas:
    betaridge1 = np.linalg.inv(Xnew_train.T.dot(Xnew_train)+(lmb*np.eye(len(Xnew_train[0])))).dot(Xnew_train.T).dot(z_train)
    j = 0
    for train_inds, test_inds in kfold.split(x):
        Xtrain_r = X_new[train_inds]
        ztrain_r = z_1[train_inds]

        Xtest_r = X_new[test_inds]
        ztest_r = z_true[test_inds]
        
        zpred_r = Xtest_r @ betaridge1

        mse_scores_KFold[i,j] = np.sum((zpred_r - ztest_r)**2)/np.size(zpred_r)
        #r2_scores_KFold[i,j] = 1 - np.sum((ztest_r - zpred_r) ** 2) / np.sum((ztest_r - np.mean(zpred_r)) ** 2)

        j += 1
    i += 1

estimated_mse_KFold = np.mean(mse_scores_KFold, axis = 1)
#estimated_r2_KFold = np.mean(r2_scores_KFold, axis = 1)

# %% [markdown]
# Remove intercept column! Use centered data because now the intercept is penalized as well. Scikitlearn does this automatically, so you can test with sklearn. however this expects you to remove the intercept column as well.

# %%
plt.figure()

plt.plot(np.log10(lambdas), estimated_mse_KFold, 'r--', label = 'mse_KFold')

plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# The same with sklearn and GridSearchCV

# %%
param_grid = {'alpha': lambdas}

ridge = Ridge()

ridge_regressor = GridSearchCV(ridge, param_grid, scoring='neg_mean_squared_error', cv=5)
ridge_regressor.fit(Xnew_train, z_train)

print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 5.642908471262542e-05}
# -0.08600217659412307

# %% [markdown]
# # Part E) Lasso Regression on the Franke function with resampling

# %%
lasso = Lasso()

lasso_regressor = GridSearchCV(lasso, param_grid, scoring='neg_mean_squared_error', cv=5)
lasso_regressor.fit(Xnew_train, z_train)

print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253.3128741642369, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247.55817516516672, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 248.328460084858, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 249.9777403208929, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 242.80735052099175, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250.54008381029269, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244.80720047967353, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 245.56332127375993, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247.24962193929983, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 239.6893279745235, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247.47605502983268, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 241.87997774830293, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 242.59143240536847, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244.3360260541297, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 236.69734444959028, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244.36857009743022, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238.6334138345837, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 239.242702021181, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 241.22346529629064, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233.55035092064446, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 241.074524561651, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235.2603779528716, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235.92299912692877, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237.89994944200174, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 230.1992598380767, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237.47527203890797, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231.86512962530216, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232.3988876511811, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234.34326605972586, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226.63834843893443, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233.67903932700165, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228.2772435580489, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228.63684474593052, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 230.5516161119923, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222.855527765069, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 229.63225116134822, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224.2270090078834, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224.62478821586865, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226.42150956407752, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 218.631084218407, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225.3088127613019, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219.9134811366967, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220.35628772902157, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222.4363501264741, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214.21668548788884, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220.68137449822652, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215.4009039857927, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215.81797823770978, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219.53930086142475, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209.54374547769913, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215.6929765415988, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 210.63715225029813, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 211.39019617137546, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 213.3363441482815, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204.59732786825236, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 210.0659503475016, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205.59233108628428, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206.54265514454553, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 208.24130344346378, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199.35508870258784, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.50921168750824, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 200.09540272199257, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 198.66410863397832, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202.82570431209064, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.77904849410157, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206.87105414582265, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.86269583087878, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.51286796022777, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196.73752141211463, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187.84235714946527, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 191.31987439236497, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187.11601178994525, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186.1794277825852, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190.01248050720358, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181.3957586313016, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183.81650397460564, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179.87797916665613, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177.6678352632381, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182.80640087756223, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174.26636886353123, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175.88011969781607, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172.10494753518088, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174.12271629025844, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175.0842862485142, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166.23068688929953, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167.9929991323564, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163.73741096884564, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163.92895182944494, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166.79631799720372, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157.2856233907991, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159.63101762502959, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154.78966761347442, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155.65058361369296, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157.89051880034808, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.55649070037856, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150.80055228393942, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.01105609290204, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.9117412214055, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148.31340330737112, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148.4216477860145, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139.10375373125203, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135.10461953008644, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137.71248157818954, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139.32489702776107, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.53104682559604, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.29954629870323, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.39421741843893, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128.802916950504, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.0212135488766, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.72027633132012, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118.82635852649341, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.0778647787977, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118.77009116003322, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118.86980365740766, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.47649418463098, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107.81662409183897, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.28335625378605, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108.31442790571293, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.51167218969834, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.84972765537157, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.36521803053077, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.06097175115445, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.36053136339655, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94.41952424465646, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87.87602010299156, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.49748203445495, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.48105664183754, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.52504776478656, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82.81970232838006, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.62671648397077, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71.22666775514267, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.69799418820526, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.056974134526, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.9046073918908, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.95596931365219, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.76513234857083, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.050243725091605, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60.764016538543274, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.840498284319835, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.82136245315456, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.46962800833484, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.74327190965789, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.413217912041375, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.27529749736817, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.84601341145731, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.3789514817297, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.035399476009786, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.12623496251399, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.619249783760324, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.12624984019419, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.421123371940666, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.63826564626709, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.02098032439079, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.140032815729285, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.46607373513939, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.59569538285848, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.87563375463401, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.53518615835827, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.627202856602935, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.351715153779935, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.4500101635947, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.92019135695324, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.13850553147489, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.14795248565315, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.06456307715581, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.826933421218087, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.34792969722406, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.78805080231865, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.67767160027398, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.698973390037963, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.892535004573915, tolerance: 0.10602958237355922
#   positive)
# ...
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.203823985518852, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.726374073297279, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6394347873865627, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3279516180818973, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.7337834682721223, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2512346600603905, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6329888470678497, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.588841164532937, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3439451101442046, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5556073855158274, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2907277311632015, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4425329333952277, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4630287069405767, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3756140182457557, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5122221384555132, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3111851859732724, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.569016097970348, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.365905599865755, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.460686650707089, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5900799303816484, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6517103453347772, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.586777158870177, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2481466668677967, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5717174926280677, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5886142149327043, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6867536146706925, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.588394805122789, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.25283015831576, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7516285198679498, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0699666572786555, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7061979425134268, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5511250194410877, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.289714730129049, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6819544124632557, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4182833232501935, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7325362014706798, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8530626240736865, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4175540299615932, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9389971286842638, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1563468054229133, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7372508984424258, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1905115520153231, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26300491398092163, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5807497744257262, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.277419542113762, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7299506929383597, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1305179628766382, tolerance: 0.10626982181742566
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16416547498590717, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1979347637433193, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0999711889892296, tolerance: 0.10410702637823893
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.243068270702338, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10844972054906066, tolerance: 0.10482442310776681
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14404980565234382, tolerance: 0.10602958237355922
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5186406382016457, tolerance: 0.10589352901841685
#   positive)
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24575504578615437, tolerance: 0.10589352901841685
#   positive)
# {'alpha': 1e-05}
# -0.09084980817656867
# /Users/jolyndevis/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 310.7489286801821, tolerance: 0.13178289334544172
#   positive)

# %%
clf_lasso = skl.Lasso(alpha=0.01).fit(Xtrain_poly, z_train)
zlasso = clf_lasso.predict(Xtest_poly)

# %%
print(MSE(z_test, zlasso))

# %%
print(R2(z_test, zlasso))

# %% [markdown]
# The smaller alpha gets, the lower the MSE and the higher the R2 score.
